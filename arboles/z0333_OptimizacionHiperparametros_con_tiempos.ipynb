# %% [markdown]
# # 3 Optimización de Hiperpárametros

# %% [markdown]
# ## 3.01 Introduccion
# En general los algoritmos que generan modelos predictivos poseen hiperparámetros que *dado un dataset* deben ser optimizados.
# <br> La invocación de uno de esos algoritmos sin hiperparámetros no es más que
# invocarlos con hiperparámetros por default definidos por el fabricante. Por ejemplo en el caso de la librería **rpart** es cp=0.01, maxdepth=30, minsplit=20, minbucket=6,  lo que en nuestro dataset genera un arbol de un solo nodo (decimos "no se abre el arbol"); la razon de esto es la proporcion de "BAJA+1" y "BAJA+2"

# %% [markdown]
# En el primer notebook de la asignatura usted probó optimizar manualmente los hiperparámetros entrenando en un mes completo y viendo los resultados directamente en el Public Leaderboard, que es una porción de los datos de futuro.
# <br> En el mundo real no se dispone jamás de la clase del futuro, con lo cual lo anterior es meramente un artifical divertimento.
# <br> La solución es estimar la bondad de un set de hiperparámetros en alguna combinación de:
#   * Una sola partición de  <training, testing>
#   * Multiples particiones de <training, testing>
#   * El método de  k-fold Cross Validation , generalmente con n>=5
#   * Utilizar   n-repated  k-fold Cross Validation
#   * Leave One Out  si la cardinalidad del dataset y el poder de cómputo se lo permiten

# %% [markdown]
# Luego de comenzar a trabajar con el método de  "Multiples particiones de <training, testing>  se le invitó a extender un esqueleto de código del método de **Optimización de Hiperparámetros por Grid Search**

# %% [markdown]
# ## 3.02 Conceptos
#
# En esta entrega veremos los siguiente conceptos:
# * El origen del overfitting en un arbol de decisión
# * *La maldición del ganador*, overfitting en los hiperparámetros ganadores, Selective Inference
# * Data Drifting
# * Alterntivas de búsqueda
#   * Grid Search, la fuerza bruta
#   * Bayesian Optimization, la heurística

# %% [markdown]
# ## 3.04 Origen del Overfitting en un arbol de decisión
# ¿Qué combinacion de hiperparámetros overfitea un árbol de decisión, para nuestro dataset?
# <br>¿Cómo se ve el overfitting desde el punto de vista de las curvas de ganancia?

# %% [markdown]
# El objetivo de este capítulo es que usted juegue manualmente con los hiperparámetros de un rpart, observe las curvas de ganancia generadas en una particion <training=50%, testing=50%>  y obtengla conclusiones sobre el fenómeno observado.

# %% [markdown]
# Introducimos el concepto de **Curva de Ganancia**
# <br> Al aplicar un modelo a un dataset se le asigna a cada registro una probabilidad, a su vez cada registro contribuye con una ganancia la que puede ser una pérdida o una ganancia.
# <br>Ordenamos el dataset por probabilidad *descendente* y computamos la ganancia acumulada, generando de esta forma la curva de ganancia
# <br> Para visualizar el efecto del under/over  fitting adecuadamente, realizamos una particion  <training= 50%, testing= 50%>

# %% [markdown]
# tener presente:
# <br> Overfitting  **NO**  es la diferencia entre las curvas
# <br> Lo que divide el underfitting del overfitting al aumentar la complejidad del modelo es la complejidad donde se alcanza la métrica máxima.

# %% [markdown]
# ### ¿Qué debe hacer usted?
# Probar al menos estas combinaciones:
# * **Arbol crecimiento descontrolado**
#    * cp= -1
#    * maxdepth= 30
#    * minsplit= 2
#    * minbucket= 1
# * Arbol talla reducida
#    * cp= -1
#    * maxdepth= 3
#    * minsplit= 20000
#    * minbucket= 10000

# %% [markdown]
# #### Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   Bajar el  **competencia_01_crudo**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dmeyf"
mkdir -p "/content/buckets"
ln -sfn "/content/.drive/My Drive/dmeyf" /content/buckets/b1


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


# defino funcion descargar()
descargar() {
  carpeta_destino="/content/buckets/b1/datasets/"
  url_origen="https://storage.googleapis.com/open-courses/dmeyf2026-9c6f/"
  archivo="$1"

  if ! test -f "$carpeta_destino""$archivo"; then
    wget  "$url_origen""$archivo"  -O "$carpeta_destino""$archivo"
  fi

  if ! test -f  "/content/datasets/""$archivo"; then
    cp  "$carpeta_destino""$archivo"  "/content/datasets/""$archivo"
  fi;
}


# hago la descarga efectiva, llamando a descargar()
descargar  "competencia_01_crudo.csv"

# %% [markdown]
# ## Generacion de la clase_ternaria

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Tipe -> Runtime type -> R

# %%
require( "data.table" )

# leo el dataset
dataset <- fread("/content/datasets/competencia_01_crudo.csv" )

# calculo el periodo0 consecutivo
dsimple <- dataset[, list(
    "pos" = .I,
    numero_de_cliente,
    periodo0 = as.integer(foto_mes/100)*12 +  foto_mes%%100 ) ]


# ordeno
setorder( dsimple, numero_de_cliente, periodo0 )

# calculo topes
periodo_ultimo <- dsimple[, max(periodo0) ]
periodo_anteultimo <- periodo_ultimo - 1


# calculo los leads de orden 1 y 2
dsimple[, c("periodo1", "periodo2") :=
    shift(periodo0, n=1:2, fill=NA, type="lead"),  numero_de_cliente ]

# assign most common class values = "CONTINUA"
dsimple[ periodo0 < periodo_anteultimo, clase_ternaria := "CONTINUA" ]

# calculo BAJA+1
dsimple[ periodo0 < periodo_ultimo &
    ( is.na(periodo1) | periodo0 + 1 < periodo1 ),
    clase_ternaria := "BAJA+1" ]

# calculo BAJA+2
dsimple[ periodo0 < periodo_anteultimo & (periodo0+1 == periodo1 )
    & ( is.na(periodo2) | periodo0 + 2 < periodo2 ),
    clase_ternaria := "BAJA+2" ]


# pego el resultado en el dataset original y grabo
setorder( dsimple, pos )
dataset[, clase_ternaria := dsimple$clase_ternaria ]

fwrite( dataset,
    file =  "/content/datasets/competencia_01.csv.gz",
    sep = ","
)
# Out:
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following object is masked from ‘package:base’:
#
#     %notin%

# %%
setorder( dataset, foto_mes, clase_ternaria, numero_de_cliente)
dataset[, .N, list(foto_mes, clase_ternaria)]
# Out:
#    foto_mes clase_ternaria N
# 1  202103   BAJA+1           1019
# 2  202103   BAJA+2            960
# 3  202103   CONTINUA       160921
# 4  202104   BAJA+1            964
# 5  202104   BAJA+2           1139
# 6  202104   CONTINUA       161181
# 7  202105   BAJA+1           1143
# 8  202105   BAJA+2            870
# 9  202105   CONTINUA       161755
# 10 202106   BAJA+1            874
# 11 202106   BAJA+2           1098
# 12 202106   CONTINUA       162142
# 13 202107   NA             163245
# 14 202107   BAJA+1           1103
# 15 202108   NA             164647

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb)   max used  (Mb)
# Ncells  740029 39.6   1473300    78.7   1473300   78.7
# Vcells 1388318 10.6 170859661  1303.6 212615883 1622.2

# %%
# cargo las librerias que necesito
require("data.table")
require("rpart")
require("ggplot2")
# Out:
# Loading required package: rpart
#
# Loading required package: ggplot2

# %%
if(!require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %%
# carpeta de trabajo
setwd("/content/buckets/b1/exp")
experimento <- "exp304"
dir.create(experimento, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# ### Acción :  Jugar con  minsplit, minbucket y maxdepth

# %% [markdown]
# Probar al menos estas combinaciones:
#
# Arbol crecimiento descontrolado
# cp= -1
# maxdepth= 30
# minsplit= 2
# minbucket= 1 <br>
# Arbol talla reducida
# cp= -1
# maxdepth= 3
# minsplit= 20000
# minbucket= 10000

# %%
# cambiar aqui los parametros
PARAM <- list()
PARAM$semilla_primigenia <- 230047

PARAM$minsplit <- 5000
PARAM$minbucket <- 2000
PARAM$maxdepth <- 10

# %%
# particionar agrega una columna llamada fold a un dataset
#   que consiste en una particion estratificada segun agrupa
# particionar( data=dataset, division=c(70,30),
#  agrupa=clase_ternaria, seed=semilla)   crea una particion 70, 30

particionar <- function(data, division, agrupa= "", campo= "fold", start= 1, seed= NA) {
  if (!is.na(seed)) set.seed(seed)

  bloque <- unlist(mapply(
    function(x, y) {rep(y, x)},division, seq(from= start, length.out= length(division))))

  data[, (campo) := sample(rep(bloque,ceiling(.N / length(bloque))))[1:.N],by= agrupa]
}

# %%
# lectura del dataset
dataset <- fread("/content/datasets/competencia_01.csv.gz")

# %%
# a partir de ahora solo trabajo con 202106, el ultimo mes que tiene clase

dataset <- dataset[foto_mes == 202106] # defino donde voy a entrenar

# %%
# La division training/testing es 50%, 50%
#  que sea 50/50 se indica con el c(1,1)

particionar(dataset,
  division= c(1, 1),
  agrupa= "clase_ternaria",
  seed= PARAM$semilla_primigenia
)

# %%
# Entreno el modelo
# los datos donde voy a entrenar
# aqui es donde se deben probar distintos hiperparametros

modelo <- rpart(
  formula= "clase_ternaria ~ . -fold",
  data= dataset[fold == 1, ],
  xval= 0,
  cp= -1,
  minsplit= PARAM$minsplit,
  minbucket= PARAM$minbucket,
  maxdepth= PARAM$maxdepth
)

# %%
# aplico el modelo a TODOS los datos, inclusive los de training
prediccion <- predict(modelo, dataset, type= "prob")

# %%
# Pego la probabilidad de  BAJA+2
tb_prediccion <- dataset[, list(fold,clase_ternaria)]
tb_prediccion[, prob_baja2 := prediccion[, "BAJA+2"]]

# %%
# Dibujo la curva de ganancia acumulada
setorder(tb_prediccion, fold, -prob_baja2)

# %%
# agrego una columna que es la de las ganancias
# la multiplico por 2 para que ya este normalizada
#  es 2 porque cada fold es el 50%

tb_prediccion[, gan := 2 *ifelse(clase_ternaria == "BAJA+2", 1072500, -27500)]
tb_prediccion[, ganancia_acumulada := cumsum(gan), by= fold]
tb_prediccion[, pos := sequence(.N), by= fold]

# %%
tb_prediccion
# Out:
#        fold clase_ternaria prob_baja2 gan     ganancia_acumulada pos
# 1      1    CONTINUA       0.07274556  -55000   -55000            1
# 2      1    CONTINUA       0.07274556  -55000  -110000            2
# 3      1    CONTINUA       0.07274556  -55000  -165000            3
# 4      1    CONTINUA       0.07274556  -55000  -220000            4
# 5      1    CONTINUA       0.07274556  -55000  -275000            5
# 6      1    CONTINUA       0.07274556  -55000  -330000            6
# 7      1    CONTINUA       0.07274556  -55000  -385000            7
# 8      1    CONTINUA       0.07274556  -55000  -440000            8
# 9      1    CONTINUA       0.07274556  -55000  -495000            9
# 10     1    CONTINUA       0.07274556  -55000  -550000           10
# 11     1    CONTINUA       0.07274556  -55000  -605000           11
# 12     1    CONTINUA       0.07274556  -55000  -660000           12
# 13     1    CONTINUA       0.07274556  -55000  -715000           13
# 14     1    CONTINUA       0.07274556  -55000  -770000           14
# 15     1    CONTINUA       0.07274556  -55000  -825000           15
# 16     1    CONTINUA       0.07274556  -55000  -880000           16
# 17     1    CONTINUA       0.07274556  -55000  -935000           17
# 18     1    CONTINUA       0.07274556  -55000  -990000           18
# 19     1    CONTINUA       0.07274556  -55000 -1045000           19
# 20     1    CONTINUA       0.07274556  -55000 -1100000           20
# 21     1    CONTINUA       0.07274556  -55000 -1155000           21
# 22     1    CONTINUA       0.07274556  -55000 -1210000           22
# 23     1    CONTINUA       0.07274556  -55000 -1265000           23
# 24     1    BAJA+2         0.07274556 2145000   880000           24
# 25     1    BAJA+2         0.07274556 2145000  3025000           25
# 26     1    CONTINUA       0.07274556  -55000  2970000           26
# 27     1    CONTINUA       0.07274556  -55000  2915000           27
# 28     1    BAJA+1         0.07274556  -55000  2860000           28
# 29     1    CONTINUA       0.07274556  -55000  2805000           29
# 30     1    CONTINUA       0.07274556  -55000  2750000           30
# ⋮      ⋮    ⋮              ⋮          ⋮       ⋮                  ⋮
# 164085 2    CONTINUA       0          -55000  -3303740000        82028
# 164086 2    CONTINUA       0          -55000  -3303795000        82029
# 164087 2    CONTINUA       0          -55000  -3303850000        82030
# 164088 2    CONTINUA       0          -55000  -3303905000        82031
# 164089 2    CONTINUA       0          -55000  -3303960000        82032
# 164090 2    CONTINUA       0          -55000  -3304015000        82033
# 164091 2    CONTINUA       0          -55000  -3304070000        82034
# 164092 2    CONTINUA       0          -55000  -3304125000        82035
# 164093 2    CONTINUA       0          -55000  -3304180000        82036
# 164094 2    CONTINUA       0          -55000  -3304235000        82037
# 164095 2    CONTINUA       0          -55000  -3304290000        82038
# 164096 2    CONTINUA       0          -55000  -3304345000        82039
# 164097 2    CONTINUA       0          -55000  -3304400000        82040
# 164098 2    CONTINUA       0          -55000  -3304455000        82041
# 164099 2    CONTINUA       0          -55000  -3304510000        82042
# 164100 2    CONTINUA       0          -55000  -3304565000        82043
# 164101 2    CONTINUA       0          -55000  -3304620000        82044
# 164102 2    CONTINUA       0          -55000  -3304675000        82045
# 164103 2    CONTINUA       0          -55000  -3304730000        82046
# 164104 2    CONTINUA       0          -55000  -3304785000        82047
# 164105 2    CONTINUA       0          -55000  -3304840000        82048
# 164106 2    CONTINUA       0          -55000  -3304895000        82049
# 164107 2    CONTINUA       0          -55000  -3304950000        82050
# 164108 2    CONTINUA       0          -55000  -3305005000        82051
# 164109 2    CONTINUA       0          -55000  -3305060000        82052
# 164110 2    CONTINUA       0          -55000  -3305115000        82053
# 164111 2    CONTINUA       0          -55000  -3305170000        82054
# 164112 2    CONTINUA       0          -55000  -3305225000        82055
# 164113 2    CONTINUA       0          -55000  -3305280000        82056
# 164114 2    CONTINUA       0          -55000  -3305335000        82057

# %%
# agrego una columna que es la de las ganancias
# la multiplico por 2 para que ya este normalizada
#  es 2 porque cada fold es el 50%

tb_prediccion[, gan := 2 *ifelse(clase_ternaria == "BAJA+2", 1072500, -27500)]
tb_prediccion[, ganancia_acumulada := cumsum(gan), by= fold]
tb_prediccion[, pos := sequence(.N), by= fold]

# %%
# defino hasta donde muestra el grafico
amostrar <- 20000

# %%
# Esta hermosa curva muestra como en el mentiroso training
#   la ganancia es siempre mejor que en el real testing

options( repr.plot.width=10, repr.plot.height=10)

gra <- ggplot(
           data= tb_prediccion[pos <= amostrar],
           aes( x= pos, y= ganancia_acumulada,
                color= ifelse(fold == 1, "train", "test") )
             ) + geom_line()

gra <- gra + theme(text = element_text(size = 16))

options(repr.plot.width=16, repr.plot.height=9)
print( gra )
# Out:
# plot without title

# %%
print(PARAM)
cat( "Train gan max: ", tb_prediccion[fold==1, max(ganancia_acumulada)], "\n" )
cat( "Test  gan max: ", tb_prediccion[fold==2, max(ganancia_acumulada)], "\n" )
# Out:
# $semilla_primigenia
# [1] 230047
#
# $minsplit
# [1] 5000
#
# $minbucket
# [1] 2000
#
# $maxdepth
# [1] 10
#
# Train gan max:  314655000
# Test  gan max:  324280000

# %%
314655000
1149445000

# %%
# veo los resultados

print(PARAM)
cat( "Train gan max: ", tb_prediccion[fold==1, max(ganancia_acumulada)], "\n" )
cat( "Test  gan max: ", tb_prediccion[fold==2, max(ganancia_acumulada)], "\n" )
# Out:
# $semilla_primigenia
# [1] 230047
#
# $minsplit
# [1] 2
#
# $minbucket
# [1] 1
#
# $maxdepth
# [1] 30
#
# Train gan max:  1149445000
# Test  gan max:  64185000

# %% [markdown]
# ## 3.05 Análisis de la salida de Grid Search
#
# En clase utilizando un enfoque constructivista de educacion cada una de las mesas del aula analizará las salidas de las corridas de Grid Search de la Tarea para el Hogar.
# <br>Se espera que quienes ya trabajan como Data Analyst se luzcan en el análisis de esos datos
# <br>Finalmente se utilizara un *arma conceptual secreta*, iluminando elegantemente donde están las mayores ganancias.

# %% [markdown]
# ## 3.06 La Maldición del Ganador

# %% [markdown]
# ¿Los hiperparámetros ganadores de toda la cohorte, estan overfiteando?
# <br> Trabajaremos con la hoja **C3-GS Overfitting** de la Google Sheet Colaborativa
# <br> Determinar de toda la cohorte quien obtuvo la mayor ganancia y con qué hiperparámetros
# <br> copiarlos  a la hoja **C3-GS Overfitting**
# <br> Quien obtuvo esa ganancia no debe hacer nada
# <br> El resto de la cohorte, modifica su script de Grid Search para calcular la ganancia de dichos hiperparámetros ganadores  utilizando su Semilla Primigenia y registra la ganancia en la linea correspondiente a su nombre en la hoja C3-GS Overfitting

# %% [markdown]
# ¿ Como compara la ganancia del ganador versus el resto de las ganancias recién calculadas ?

# %% [markdown]
# #### Bibliografia

# %% [markdown]
# * Selective Inference - the silent killer of replicability   https://www.youtube.com/watch?v=6ZxIzVjV1DE
# * Ioannidis, J. P. A. Why most published research findings are false. PLoS Med. 2, e124 (2005). https://journals.plos.org/plosmedicine/article/file?id=10.1371/journal.pmed.0020124&type=printable

# %% [markdown]
# ---

# %% [markdown]
# ## 3.07 Bayesian Optimization

# %% [markdown]
# Se explicará en clase como a partir del Grid Search se deriva el algoritmo de Bayesian Optimization

# %% [markdown]
# ---

# %% [markdown]
# ## 3.08 Bayesian Optimization código

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb)   max used  (Mb)
# Ncells 1457280 77.9   2803257   149.8   2803257  149.8
# Vcells 2922724 22.3 175501693  1339.0 274168638 2091.8

# %% [markdown]
# * Instalacion de la libreria  rpart.plot  para dibujar el arbol
# * invocacion de las librerias  **data.table** y  **rpart**

# %%
# cargo las librerias que necesito
require("data.table")
require("rpart")
require("parallel")
# Out:
# Loading required package: parallel

# %%
if( ! require("rlist") ) install.packages("rlist")
require("rlist")
# Out:
# Loading required package: rlist
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘rlist’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘XML’
#
#
# Loading required package: rlist

# %%
if(!require("R.utils")) install.packages("R.utils")
require("R.utils")

# %%
# paquete necesarios para la Bayesian Optimization
if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging

# %%
# paquete necesarios para la Bayesian Optimization
if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Accion a realizar : cambiar por su semilla primigenia

# %%
# Defino parametros
PARAM <- list()

PARAM$semilla_primigenia <- 230047
PARAM$experimento <- "HT308"

PARAM$BO_iter <- 40 # cantidad de iteraciones de la Bayesian Optimization

# la letra L al final de 1L significa ENTERO
PARAM$hs <- makeParamSet(
    makeNumericParam("cp", lower= -1, upper= 0.1),
    makeIntegerParam("minsplit", lower= 1L, upper= 8000L),
    makeIntegerParam("minbucket", lower= 1L, upper= 4000L),
    makeIntegerParam("maxdepth", lower= 3L, upper= 20L),
    forbidden= quote(minbucket > 0.5 * minsplit)
)
# minbuket NO PUEDE ser mayor que la mitad de minsplit

# %%
# carpeta de trabajo
setwd("/content/buckets/b1/exp")
dir.create(PARAM$experimento, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", PARAM$experimento ))

# %%
particionar <- function(data, division, agrupa = "", campo = "fold",
                        start = 1, seed = NA) {
  if (!is.na(seed)) set.seed(seed)

  bloque <- unlist(mapply(
    function(x, y) {
      rep(y, x)
    }, division,
    seq(from= start, length.out= length(division))
  ))

  data[, (campo) := sample(rep(bloque, ceiling(.N / length(bloque))))[1:.N],
    by= agrupa
  ]
}

# %%
# fold_test  tiene el numero de fold que voy a usar para testear,
#  entreno en el resto de los folds
# param tiene los hiperparametros del arbol
#
# IMPORTANTE: esta funcion corre dentro de un fork de mcmapply
#  (proceso hijo), por lo tanto NO puede escribir en variables
#  globales del proceso padre (una asignacion con <<- se pierde
#  al terminar el fork). Por eso los tiempos se DEVUELVEN junto
#  con la ganancia, y se recolectan recien en el proceso padre
#  (dentro de ArbolesCrossValidation).

ArbolSimple <- function(fold_test, param_rpart) {

  # --- entrenamiento del arbol ---
  t0_train <- Sys.time()
  modelo <- rpart("clase_ternaria ~ .",
    data= dataset[fold != fold_test, ],
    xval= 0,
    control= param_rpart
  )
  t1_train <- Sys.time()

  # --- prediccion ---
  t0_pred <- Sys.time()
  prediccion <- predict(modelo,
    dataset[fold == fold_test, ],
    type= "prob"
  )
  t1_pred <- Sys.time()

  # esta es la probabilidad de baja
  prob_baja2 <- prediccion[, "BAJA+2"]

  # --- calculo de la ganancia ---
  t0_gan <- Sys.time()
  ganancia_testing <- dataset[fold == fold_test][
    prob_baja2 > 1 / 40,
    sum(ifelse(clase_ternaria == "BAJA+2",
      1072500, -27500
    ))
  ]
  t1_gan <- Sys.time()

  # esta es la ganancia sobre el fold de testing, NO esta normalizada
  # la devuelvo junto con los tiempos de cada sub-paso de este fold
  return(list(
    ganancia_testing = ganancia_testing,
    tiempos = data.table(
      paso = c("entrenamiento_arbol", "prediccion", "calculo_ganancia"),
      duracion = c(
        as.numeric(difftime(t1_train, t0_train, units= "secs")),
        as.numeric(difftime(t1_pred,  t0_pred,  units= "secs")),
        as.numeric(difftime(t1_gan,   t0_gan,   units= "secs"))
      )
    )
  ))
}

# %%
ArbolesCrossValidation <- function(param_rpart, qfolds, pagrupa, semilla) {
  # generalmente  c(1, 1, 1, 1, 1 )  cinco unos
  divi <- rep(1, qfolds)

  # --- particion ---
  t0_part <- Sys.time()
  particionar(dataset, divi, seed= semilla, agrupa= pagrupa)
  t1_part <- Sys.time()

  # --- cross validation completa ---
  # esto es tiempo de RELOJ (wall-clock): los folds corren en paralelo,
  #  por lo que NO es la suma de los tiempos de cada arbol
  t0_cv <- Sys.time()
  resultados <- mcmapply(ArbolSimple,
    seq(qfolds), # 1 2 3 4 5
    MoreArgs= list(param_rpart),
    SIMPLIFY= FALSE,
    mc.cores= detectCores()
  )
  t1_cv <- Sys.time()

  dataset[, fold := NULL]

  # cada elemento de "resultados" viene de un fork distinto y trae
  #  tanto la ganancia como los tiempos de ese fold
  ganancias <- lapply(resultados, function(r) r$ganancia_testing)
  tiempos_folds <- rbindlist(lapply(resultados, function(r) r$tiempos))

  # arma la tabla de tiempos de ESTA llamada a cross validation
  tiempos_cv <- rbindlist(list(
    data.table(
      paso= "particion",
      duracion= as.numeric(difftime(t1_part, t0_part, units= "secs"))
    ),
    tiempos_folds,
    data.table(
      paso= "cv_total_wallclock",
      duracion= as.numeric(difftime(t1_cv, t0_cv, units= "secs"))
    )
  ))

  # acumulo en la tabla GLOBAL de tiempos, marcando a que iteracion
  #  de la Bayesian Optimization pertenece
  GLOBAL_tiempos <<- rbindlist(list(
    GLOBAL_tiempos,
    tiempos_cv[, iteracion := GLOBAL_iteracion][, .(iteracion, paso, duracion)]
  ))

  # devuelvo la primer ganancia y el promedio
  # promedio las ganancias
  ganancia_promedio <- mean(unlist(ganancias))
  # aqui normalizo la ganancia
  ganancia_promedio_normalizada <- ganancia_promedio * qfolds

  return(ganancia_promedio_normalizada)
}

# %%
# esta funcion solo puede recibir los parametros que se estan optimizando
# el resto de los parametros, lamentablemente se pasan como variables globales

# GLOBAL_fin_anterior guarda el timestamp de fin de la iteracion previa,
#  para poder estimar cuanto tardo mlrMBO en SUGERIR el proximo punto
#  (ajuste del modelo kriging + optimizacion del infill criterion).
#  Es una aproximacion: todo lo que paso entre que termino una
#  llamada a EstimarGanancia y empezo la siguiente.

EstimarGanancia <- function(x) {
  t0_iter <- Sys.time()
  message(format(t0_iter, "%a %b %d %X %Y"))

  if (!is.na(GLOBAL_fin_anterior)) {
    GLOBAL_tiempos <<- rbindlist(list(
      GLOBAL_tiempos,
      data.table(
        iteracion= GLOBAL_iteracion + 1,
        paso= "sugerencia_bo",
        duracion= as.numeric(difftime(t0_iter, GLOBAL_fin_anterior, units= "secs"))
      )
    ))
  }

  GLOBAL_iteracion <<- GLOBAL_iteracion + 1

  xval_folds <- 5
  # param= x los hiperparametros del arbol
  # qfolds= xval_folds  la cantidad de folds
  ganancia <- ArbolesCrossValidation(
    param_rpart= x,
    qfolds= xval_folds,
    pagrupa= "clase_ternaria",
    semilla= PARAM$semilla_primigenia
  )

  t1_iter <- Sys.time()
  GLOBAL_tiempos <<- rbindlist(list(
    GLOBAL_tiempos,
    data.table(
      iteracion= GLOBAL_iteracion,
      paso= "estimar_ganancia_total",
      duracion= as.numeric(difftime(t1_iter, t0_iter, units= "secs"))
    )
  ))

  GLOBAL_fin_anterior <<- t1_iter

  return(ganancia)
}

# %%
# leo el dataset
dataset <- fread("/content/datasets/competencia_01.csv.gz")

# %%
dataset <- dataset[foto_mes==202104]

# %%
archivo_log <- "BO_log.txt"
archivo_BO <- "bayesian.RDATA"
archivo_tiempos <- "tiempos_log.txt"

# leo si ya existe el log
#  para retomar en caso que se se corte el programa
GLOBAL_iteracion <- 0
GLOBAL_mejor <- -Inf
GLOBAL_fin_anterior <- NA  # timestamp de fin de la iteracion anterior

if (file.exists(archivo_log)) {
  tabla_log <- fread(archivo_log)
  GLOBAL_iteracion <- nrow(tabla_log)
  GLOBAL_mejor <- tabla_log[, max(y)]
}

# tabla GLOBAL donde se van acumulando los tiempos de cada paso
#  (particion, entrenamiento_arbol, prediccion, calculo_ganancia,
#   cv_total_wallclock, sugerencia_bo, estimar_ganancia_total)
# si ya existe en disco (por ejemplo porque se corto la corrida),
#  se retoma en lugar de empezar de cero
if (file.exists(archivo_tiempos)) {
  GLOBAL_tiempos <- fread(archivo_tiempos)
} else {
  GLOBAL_tiempos <- data.table(
    iteracion= integer(),
    paso= character(),
    duracion= numeric()
  )
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

funcion_optimizar <- EstimarGanancia

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,
#  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
# minimize= FALSE estoy Maximizando la ganancia
obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar,
  minimize= FALSE,
  noisy= TRUE,
  par.set= PARAM$hs,
  has.simple.signature= FALSE
)

ctrl <- makeMBOControl(
  save.on.disk.at.time= 600,
  save.file.path= archivo_BO
)

ctrl <- setMBOControlTermination(ctrl, iters= PARAM$BO_iter)
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

surr.km <- makeLearner("regr.km",
  predict.type= "se",
  covtype= "matern3_2", control= list(trace= TRUE)
)

# %%
# inicio la optimizacion bayesiana
if (!file.exists(archivo_BO)) {
  bayesiana_salida <- mbo(
    fun= obj.fun,
    learner= surr.km,
    control= ctrl
  )
} else {
  bayesiana_salida <- mboContinue(archivo_BO)
}
# retomo en caso que ya exista
# Out:
# Computing y column(s) for design. Not provided.
#
# Mon Aug 31 12:32:24 PM 2026
#
# Mon Aug 31 12:38:54 PM 2026
#
# Mon Aug 31 12:45:00 PM 2026
#
# Mon Aug 31 12:49:41 PM 2026
#
# Mon Aug 31 12:55:51 PM 2026
#
# Mon Aug 31 01:02:40 PM 2026
#
# Mon Aug 31 01:04:51 PM 2026
#
# Mon Aug 31 01:12:24 PM 2026
#
# Mon Aug 31 01:16:41 PM 2026
#
# Mon Aug 31 01:23:10 PM 2026
#
# Mon Aug 31 01:23:29 PM 2026
#
# Mon Aug 31 01:27:27 PM 2026
#
# Mon Aug 31 01:33:03 PM 2026
#
# Mon Aug 31 01:38:01 PM 2026
#
# Mon Aug 31 01:40:04 PM 2026
#
# Mon Aug 31 01:44:06 PM 2026
#
# [mbo] 0: cp=-0.815; minsplit=4172; minbucket=1077; maxdepth=13 : y = 3.84e+08 : 389.5 secs : initdesign
#
# [mbo] 0: cp=-0.192; minsplit=5600; minbucket=1674; maxdepth=20 : y = 3.68e+08 : 366.6 secs : initdesign
#
# [mbo] 0: cp=-0.114; minsplit=6311; minbucket=1842; maxdepth=10 : y = 3.61e+08 : 280.9 secs : initdesign
#
# [mbo] 0: cp=-0.72; minsplit=1487; minbucket=219; maxdepth=11 : y = 4.46e+08 : 369.9 secs : initdesign
#
# [mbo] 0: cp=-0.893; minsplit=7104; minbucket=359; maxdepth=17 : y = 3.58e+08 : 409.0 secs : initdesign
#
# [mbo] 0: cp=-0.584; minsplit=7575; minbucket=2021; maxdepth=4 : y = 3.58e+08 : 130.9 secs : initdesign
#
# [mbo] 0: cp=-0.0428; minsplit=1588; minbucket=682; maxdepth=18 : y = 4.42e+08 : 453.0 secs : initdesign
#
# [mbo] 0: cp=-0.928; minsplit=3056; minbucket=1233; maxdepth=6 : y = 3.89e+08 : 257.2 secs : initdesign
#
# [mbo] 0: cp=-0.804; minsplit=1969; minbucket=259; maxdepth=15 : y = 4.32e+08 : 389.3 secs : initdesign
#
# [mbo] 0: cp=0.0212; minsplit=6117; minbucket=2553; maxdepth=8 : y = 0 : 18.3 secs : initdesign
#
# [mbo] 0: cp=-0.351; minsplit=7792; minbucket=2051; maxdepth=11 : y = 3.58e+08 : 237.9 secs : initdesign
#
# [mbo] 0: cp=-0.0627; minsplit=4433; minbucket=529; maxdepth=17 : y = 3.78e+08 : 336.5 secs : initdesign
#
# [mbo] 0: cp=-0.702; minsplit=5739; minbucket=1896; maxdepth=19 : y = 3.68e+08 : 298.0 secs : initdesign
#
# [mbo] 0: cp=-0.386; minsplit=3175; minbucket=870; maxdepth=3 : y = 3.59e+08 : 123.1 secs : initdesign
#
# [mbo] 0: cp=-0.795; minsplit=7862; minbucket=2937; maxdepth=8 : y = 3.58e+08 : 242.2 secs : initdesign
#
# [mbo] 0: cp=-0.743; minsplit=5015; minbucket=432; maxdepth=17 : y = 3.71e+08 : 387.2 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesian.RDATA.
#
# Mon Aug 31 01:50:36 PM 2026
#
# [mbo] 1: cp=-0.0971; minsplit=865; minbucket=334; maxdepth=20 : y = 4.41e+08 : 494.8 secs : infill_ei
#
# Mon Aug 31 01:58:52 PM 2026
#
# [mbo] 2: cp=-0.77; minsplit=638; minbucket=252; maxdepth=6 : y = 4.4e+08 : 232.7 secs : infill_ei
#
# Saved the current state after iteration 3 in the file bayesian.RDATA.
#
# Mon Aug 31 02:02:46 PM 2026
#
# [mbo] 3: cp=-0.0826; minsplit=1969; minbucket=1; maxdepth=10 : y = 4.07e+08 : 370.7 secs : infill_ei
#
# Mon Aug 31 02:08:59 PM 2026
#
# [mbo] 4: cp=-0.736; minsplit=11; minbucket=5; maxdepth=20 : y = 1.8e+08 : 813.5 secs : infill_ei
#
# Saved the current state after iteration 5 in the file bayesian.RDATA.
#
# Mon Aug 31 02:22:34 PM 2026
#
# [mbo] 5: cp=-0.778; minsplit=1348; minbucket=5; maxdepth=10 : y = 4.13e+08 : 474.3 secs : infill_ei
#
# Mon Aug 31 02:30:32 PM 2026
#
# [mbo] 6: cp=-0.708; minsplit=1965; minbucket=484; maxdepth=7 : y = 4.38e+08 : 287.2 secs : infill_ei
#
# Saved the current state after iteration 7 in the file bayesian.RDATA.
#
# Mon Aug 31 02:35:21 PM 2026
#
# [mbo] 7: cp=-0.106; minsplit=215; minbucket=106; maxdepth=15 : y = 3.52e+08 : 580.6 secs : infill_ei
#
# Mon Aug 31 02:45:05 PM 2026
#
# [mbo] 8: cp=-0.445; minsplit=750; minbucket=139; maxdepth=13 : y = 4.18e+08 : 500.0 secs : infill_ei
#
# Saved the current state after iteration 9 in the file bayesian.RDATA.
#
# Mon Aug 31 02:53:26 PM 2026
#
# [mbo] 9: cp=-0.99; minsplit=1585; minbucket=206; maxdepth=6 : y = 4.24e+08 : 241.8 secs : infill_ei
#
# Mon Aug 31 02:57:30 PM 2026
#
# [mbo] 10: cp=0.0997; minsplit=1519; minbucket=752; maxdepth=4 : y = 0 : 16.6 secs : infill_ei
#
# Mon Aug 31 02:57:48 PM 2026
#
# [mbo] 11: cp=-0.25; minsplit=1328; minbucket=4; maxdepth=10 : y = 4.14e+08 : 358.7 secs : infill_ei
#
# Saved the current state after iteration 12 in the file bayesian.RDATA.
#
# Mon Aug 31 03:03:49 PM 2026
#
# [mbo] 12: cp=-0.584; minsplit=395; minbucket=181; maxdepth=11 : y = 4.17e+08 : 408.7 secs : infill_ei
#
# Mon Aug 31 03:10:40 PM 2026
#
# [mbo] 13: cp=0.0844; minsplit=1016; minbucket=507; maxdepth=20 : y = 0 : 17.4 secs : infill_ei
#
# Mon Aug 31 03:10:59 PM 2026
#
# [mbo] 14: cp=-0.0775; minsplit=1957; minbucket=932; maxdepth=20 : y = 4.16e+08 : 436.4 secs : infill_ei
#
# Saved the current state after iteration 15 in the file bayesian.RDATA.
#
# Mon Aug 31 03:18:17 PM 2026
#
# [mbo] 15: cp=-0.818; minsplit=981; minbucket=485; maxdepth=3 : y = 3.73e+08 : 130.6 secs : infill_ei
#
# Mon Aug 31 03:20:30 PM 2026
#
# [mbo] 16: cp=-0.0522; minsplit=797; minbucket=3; maxdepth=20 : y = 3.97e+08 : 914.9 secs : infill_ei
#
# Saved the current state after iteration 17 in the file bayesian.RDATA.
#
# Mon Aug 31 03:35:47 PM 2026
#
# [mbo] 17: cp=-0.665; minsplit=3980; minbucket=1878; maxdepth=14 : y = 3.73e+08 : 381.6 secs : infill_ei
#
# Mon Aug 31 03:42:10 PM 2026
#
# [mbo] 18: cp=-0.72; minsplit=5206; minbucket=229; maxdepth=10 : y = 3.65e+08 : 328.5 secs : infill_ei
#
# Saved the current state after iteration 19 in the file bayesian.RDATA.
#
# Mon Aug 31 03:47:41 PM 2026
#
# [mbo] 19: cp=-0.0964; minsplit=835; minbucket=415; maxdepth=18 : y = 4.37e+08 : 526.9 secs : infill_ei
#
# Mon Aug 31 03:56:30 PM 2026
#
# [mbo] 20: cp=-0.741; minsplit=1507; minbucket=752; maxdepth=6 : y = 4.26e+08 : 201.6 secs : infill_ei
#
# Saved the current state after iteration 21 in the file bayesian.RDATA.
#
# Mon Aug 31 03:59:54 PM 2026
#
# [mbo] 21: cp=-0.162; minsplit=1529; minbucket=350; maxdepth=20 : y = 4.41e+08 : 472.8 secs : infill_ei
#
# Mon Aug 31 04:07:49 PM 2026
#
# [mbo] 22: cp=-0.679; minsplit=443; minbucket=75; maxdepth=6 : y = 4.22e+08 : 269.3 secs : infill_ei
#
# Saved the current state after iteration 23 in the file bayesian.RDATA.
#
# Mon Aug 31 04:12:20 PM 2026
#
# [mbo] 23: cp=-0.476; minsplit=477; minbucket=229; maxdepth=8 : y = 4.3e+08 : 319.1 secs : infill_ei
#
# Mon Aug 31 04:17:42 PM 2026
#
# [mbo] 24: cp=-0.94; minsplit=2020; minbucket=253; maxdepth=15 : y = 4.32e+08 : 439.6 secs : infill_ei
#
# Saved the current state after iteration 25 in the file bayesian.RDATA.
#
# Mon Aug 31 04:25:03 PM 2026
#
# [mbo] 25: cp=-0.522; minsplit=2237; minbucket=203; maxdepth=11 : y = 4.07e+08 : 342.0 secs : infill_ei
#
# Mon Aug 31 04:30:47 PM 2026
#
# [mbo] 26: cp=-1; minsplit=11; minbucket=4; maxdepth=12 : y = 3.29e+08 : 493.5 secs : infill_ei
#
# Saved the current state after iteration 27 in the file bayesian.RDATA.
#
# Mon Aug 31 04:39:02 PM 2026
#
# [mbo] 27: cp=-0.191; minsplit=4208; minbucket=201; maxdepth=10 : y = 3.74e+08 : 326.7 secs : infill_ei
#
# Mon Aug 31 04:44:33 PM 2026
#
# [mbo] 28: cp=-0.382; minsplit=38; minbucket=14; maxdepth=10 : y = 3.69e+08 : 407.7 secs : infill_ei
#
# Saved the current state after iteration 29 in the file bayesian.RDATA.
#
# Mon Aug 31 04:51:23 PM 2026
#
# [mbo] 29: cp=-0.113; minsplit=1553; minbucket=263; maxdepth=19 : y = 4.49e+08 : 488.5 secs : infill_ei
#
# Mon Aug 31 04:59:34 PM 2026
#
# [mbo] 30: cp=-0.275; minsplit=229; minbucket=112; maxdepth=20 : y = 3.53e+08 : 556.9 secs : infill_ei
#
# Saved the current state after iteration 31 in the file bayesian.RDATA.
#
# Mon Aug 31 05:08:52 PM 2026
#
# [mbo] 31: cp=-0.874; minsplit=2521; minbucket=302; maxdepth=15 : y = 4.21e+08 : 357.4 secs : infill_ei
#
# Mon Aug 31 05:14:51 PM 2026
#
# [mbo] 32: cp=-0.768; minsplit=7507; minbucket=3746; maxdepth=16 : y = 3.58e+08 : 208.0 secs : infill_ei
#
# Mon Aug 31 05:18:21 PM 2026
#
# [mbo] 33: cp=-0.708; minsplit=149; minbucket=19; maxdepth=12 : y = 3.57e+08 : 473.8 secs : infill_ei
#
# Saved the current state after iteration 34 in the file bayesian.RDATA.
#
# Mon Aug 31 05:26:16 PM 2026
#
# [mbo] 34: cp=-1; minsplit=3360; minbucket=330; maxdepth=14 : y = 3.99e+08 : 359.7 secs : infill_ei
#
# Mon Aug 31 05:32:18 PM 2026
#
# [mbo] 35: cp=-0.632; minsplit=1824; minbucket=239; maxdepth=11 : y = 4.38e+08 : 351.2 secs : infill_ei
#
# Saved the current state after iteration 36 in the file bayesian.RDATA.
#
# Mon Aug 31 05:38:10 PM 2026
#
# [mbo] 36: cp=-0.152; minsplit=7880; minbucket=2; maxdepth=15 : y = 3.38e+08 : 390.8 secs : infill_ei
#
# Mon Aug 31 05:44:43 PM 2026
#
# [mbo] 37: cp=-0.568; minsplit=969; minbucket=175; maxdepth=4 : y = 4.01e+08 : 138.1 secs : infill_ei
#
# Mon Aug 31 05:47:03 PM 2026
#
# [mbo] 38: cp=-0.717; minsplit=2319; minbucket=394; maxdepth=13 : y = 4.25e+08 : 371.6 secs : infill_ei
#
# Saved the current state after iteration 39 in the file bayesian.RDATA.
#
# Mon Aug 31 05:53:16 PM 2026
#
# [mbo] 39: cp=-0.462; minsplit=5580; minbucket=2787; maxdepth=13 : y = 3.73e+08 : 260.4 secs : infill_ei
#
# Mon Aug 31 05:57:39 PM 2026
#
# [mbo] 40: cp=-0.718; minsplit=987; minbucket=244; maxdepth=7 : y = 4.61e+08 : 244.6 secs : infill_ei
#
# Saved the final state in the file bayesian.RDATA

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  list(cp, minsplit, minbucket, maxdepth)
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#            cp minsplit minbucket maxdepth
#         <num>    <int>     <int>    <int>
# 1: -0.7184216      987       244        7

# %% [markdown]
# ## 3.09 Medicion de tiempos por paso
#
# Resumen de tiempos (promedio y desvio estandar) consumidos en cada paso del proceso: sugerencia de hiperparametros por parte de la Bayesian Optimization, particion, entrenamiento de cada arbol, prediccion, calculo de ganancia, y la validacion cruzada completa (tiempo de reloj).

# %%
# grabo el log de tiempos a disco
#  (permite retomar la medicion si la corrida se corta y se reanuda)
fwrite(GLOBAL_tiempos, file= archivo_tiempos, sep= "\t")

# --- Resumen: tiempo promedio y desvio estandar consumido en cada paso ---
resumen_tiempos <- GLOBAL_tiempos[
  , .(
      promedio_segs = mean(duracion),
      sd_segs       = sd(duracion),
      n             = .N
    ),
  by= paso
][order(-promedio_segs)]

print(resumen_tiempos)

# %%
# --- Grafico: distribucion de tiempos por paso ---
require("ggplot2")

options(repr.plot.width= 12, repr.plot.height= 7)

gra <- ggplot(GLOBAL_tiempos, aes(x= paso, y= duracion)) +
  geom_boxplot() +
  labs(
    title= "Distribucion de tiempos por paso del proceso de Bayesian Optimization",
    x= "Paso",
    y= "Segundos"
  ) +
  theme(axis.text.x= element_text(angle= 30, hjust= 1), text= element_text(size= 14))

print(gra)

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Aug 31 06:02:32 PM 2026"

# %% [markdown]
# ---
